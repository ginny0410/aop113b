# %% [markdown]
# <a href="https://colab.research.google.com/github/ginny0410/aop113b/blob/main/EX03_03_%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%8C%87%E6%A8%99(AQI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant    status  so2    co    o3  o3_8hr   pm10  \
# 0       基隆    基隆市  100      懸浮微粒        普通  2.4  0.24  78.0      65   82.0
# 1       汐止    新北市  102      懸浮微粒  對敏感族群不健康  4.5  0.21  73.0      60   84.0
# 2       萬里    新北市  112     臭氧八小時  對敏感族群不健康  2.1  0.26  86.0      74  101.0
# 3       新店    新北市  115     臭氧八小時  對敏感族群不健康  5.3  0.32  78.0      75   88.0
# 4       土城    新北市  115     臭氧八小時  對敏感族群不健康  2.0  0.28  79.0      75   88.0
#
#    ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# 0  ...           1         331  2025/04/17 16:00:00     0.2      27.1
# 1  ...           2          15  2025/04/17 16:00:00     0.3      25.8
# 2  ...         1.7          52  2025/04/17 16:00:00     0.2      25.3
# 3  ...         1.5           7  2025/04/17 16:00:00     0.3      25.7
# 4  ...         1.5         230  2025/04/17 16:00:00     0.4      32.3
#
#   pm10_avg so2_avg   longitude   latitude  siteid
# 0       75       1  121.760056  25.129167       1
# 1       79       2  121.640810  25.066240       2
# 2      101       1  121.689881  25.179667       3
# 3       74       0  121.537778  24.977222       4
# 4       90       1  121.451861  24.982528       5
#
# [5 rows x 24 columns]

# %%
df = df[['sitename','county','pollutant','status','aqi']]

# %%
condition = df['aqi'] > 100
df[condition]
# Out:
#    sitename county pollutant    status  aqi
# 1        汐止    新北市      懸浮微粒  對敏感族群不健康  102
# 2        萬里    新北市     臭氧八小時  對敏感族群不健康  112
# 3        新店    新北市     臭氧八小時  對敏感族群不健康  115
# 4        土城    新北市     臭氧八小時  對敏感族群不健康  115
# 5        板橋    新北市     臭氧八小時  對敏感族群不健康  108
# 6        新莊    新北市      懸浮微粒  對敏感族群不健康  104
# 7        菜寮    新北市      懸浮微粒  對敏感族群不健康  102
# 8        林口    新北市      懸浮微粒  對敏感族群不健康  104
# 9        淡水    新北市      懸浮微粒  對敏感族群不健康  106
# 10       士林    臺北市      懸浮微粒  對敏感族群不健康  103
# 11       中山    臺北市      懸浮微粒  對敏感族群不健康  104
# 13       古亭    臺北市      懸浮微粒  對敏感族群不健康  101
# 14       松山    臺北市     細懸浮微粒  對敏感族群不健康  103
# 15       大同    臺北市      懸浮微粒  對敏感族群不健康  103
# 16       桃園    桃園市      懸浮微粒  對敏感族群不健康  107
# 17       大園    桃園市      懸浮微粒  對敏感族群不健康  109
# 18       觀音    桃園市      懸浮微粒  對敏感族群不健康  105
# 19       平鎮    桃園市      懸浮微粒  對敏感族群不健康  105
# 20       龍潭    桃園市      懸浮微粒  對敏感族群不健康  103
# 21       湖口    新竹縣      懸浮微粒  對敏感族群不健康  105
# 23       新竹    新竹市      懸浮微粒  對敏感族群不健康  102
# 24       頭份    苗栗縣     臭氧八小時  對敏感族群不健康  104
# 25       苗栗    苗栗縣     臭氧八小時  對敏感族群不健康  104
# 28       沙鹿    臺中市      懸浮微粒  對敏感族群不健康  102
# 33       線西    彰化縣     臭氧八小時  對敏感族群不健康  108
# 34       二林    彰化縣      懸浮微粒  對敏感族群不健康  105
# 40       臺西    雲林縣      懸浮微粒  對敏感族群不健康  104
# 62       陽明    臺北市     臭氧八小時  對敏感族群不健康  101
# 65       三重    新北市      懸浮微粒  對敏感族群不健康  106
# 66       中壢    桃園市      懸浮微粒  對敏感族群不健康  106
# 68       永和    新北市      懸浮微粒  對敏感族群不健康  102
# 71       馬祖    連江縣      懸浮微粒  對敏感族群不健康  110
# 73       馬公    澎湖縣      懸浮微粒  對敏感族群不健康  105
# 76      富貴角    新北市     臭氧八小時  對敏感族群不健康  126
# 77       大城    彰化縣     臭氧八小時  對敏感族群不健康  112
# 84   新北（樹林）    新北市     臭氧八小時  對敏感族群不健康  122

# %%
df['pollutant'].unique()
# Out:
# array(['懸浮微粒', '臭氧八小時', '細懸浮微粒', nan], dtype=object)

# %%
condition = df['county'] == '高雄市'
df[condition]
# Out:
#    sitename county pollutant status  aqi
# 46       美濃    高雄市      懸浮微粒     普通   62
# 47       橋頭    高雄市     細懸浮微粒     普通   57
# 48       仁武    高雄市      懸浮微粒     普通   57
# 49       鳳山    高雄市      懸浮微粒     普通   60
# 50       大寮    高雄市      懸浮微粒     普通   61
# 51       林園    高雄市      懸浮微粒     普通   57
# 52       楠梓    高雄市      懸浮微粒     普通   76
# 53       左營    高雄市      懸浮微粒     普通   58
# 54       前金    高雄市      懸浮微粒     普通   64
# 55       前鎮    高雄市      懸浮微粒     普通   61
# 56       小港    高雄市      懸浮微粒     普通   59
# 69       復興    高雄市      懸浮微粒     普通   58
# 80   高雄（湖內）    高雄市      懸浮微粒     普通   72

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 連江縣    110.000000
# 新北市    109.538462
# 桃園市    105.833333
# 澎湖縣    105.000000
# 臺北市    102.142857
# 新竹市    102.000000
# 新竹縣    102.000000
# 彰化縣    101.800000
# 基隆市    100.000000
# 苗栗縣     97.333333
# 雲林縣     96.000000
# 金門縣     87.000000
# 宜蘭縣     85.333333
# 嘉義縣     82.000000
# 臺中市     79.833333
# 南投縣     77.333333
# 嘉義市     72.000000
# 花蓮縣     69.000000
# 臺南市     65.000000
# 臺東縣     65.000000
# 高雄市     61.692308
# 屏東縣     54.600000
# Name: aqi, dtype: float64
